# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data_test.csv").drop(columns=["shape"])
df
# Out:
#     0   5  10  15  20  25  30  35  40  45  ...  310  315  320  325  330  335  \
# 0  93  90  89  87  89  89  94  89  93  95  ...   88   93   90   91   90   88
#
#    340  345  350  355
# 0   93   89   90   93
#
# [1 rows x 72 columns]

# %%
# make the colums of the dataframe to a list of integers
idx_numbers = [int(idx) for idx in df.columns]

# %%
#Mitte ist 12 cm entfernt
# Invertieren der Messdaten
df = np.abs(df-110)

# %%
df
# Out:
#     0   5  10  15  20  25  30  35  40  45  ...  310  315  320  325  330  335  \
# 0  27  30  31  33  31  31  26  31  27  25  ...   32   27   30   29   30   32
#
#    340  345  350  355
# 0   27   31   30   27
#
# [1 rows x 72 columns]

# %%
fig, ax = plt.subplots(figsize=(16, 8), subplot_kw={"projection": "polar"})
#idx_numbers = [int(idx)*508/360 for idx in df.columns]
ax.scatter(idx_numbers, df.iloc[0,:])
ax.set_ylim(0, 50)
plt.show()
